# %%
from datasets import load_dataset, load_from_disk
import os

# %%
vidore_basepath = "/upb/users/a/amirk/scratch/UPB_phd/RAG"
sub_dataset_name = "vidore_v3_physics"
queries_folder_path = os.path.join(vidore_basepath, sub_dataset_name)
queries_path = os.path.join(queries_folder_path, "queries")

# %%
ds = load_from_disk(queries_path)
questions = ds["test"][:5]["query"]
gt_answers = ds["test"][:5]["answer"]

# %%
for i in range(len(questions)):
    print(questions[i])
    print(gt_answers[i])
    print("**")
